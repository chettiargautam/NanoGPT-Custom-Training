# %%
with open("data/input.txt") as f:
    text = f.read()

# %%
f"Length of characters: {len(text)}"
# Out:
# 'Length of characters: 1115394'

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)
f"Vocab size: {vocab_size}", f"All characters: {''.join(chars)}"
# Out:
# ('Vocab size: 65',
#  "All characters: \n !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz")

# %%
stoi = {c:i for i, c in enumerate(chars)}
itos = {i:c for i, c in enumerate(chars)}

encode = lambda s: [stoi[c] for c in s]
decode = lambda i: ''.join(itos[k] for k in i)

# %%
encode("hi there"), decode(encode("hi there"))
# Out:
# ([46, 47, 1, 58, 46, 43, 56, 43], 'hi there')

# %%
import torch

# %%
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:100])
# Out:
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59])

# %%
n = int(0.85 * len(data))

train_data = data[:n]
val_data = data[n:]

train_data.shape, val_data.shape
# Out:
# (torch.Size([948084]), torch.Size([167310]))

# %%
block_size = 16
train_data[:block_size+1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43])

# %% [markdown]
# ### Taking all previous inputs as context for predicting the target
#
# ##### Obtaining the next token given all previous tokens. It is sampled from the probability distribution that maps all context tokens and a distribution of next token probabilities is generated, where a sampling strategy picks the next token
# $x_{i+1} ∼ q(x_0, x_1, ..., x_i)$
#
# ##### Probability of a token being output can be obtained as the conditional probability of the trained distribution given all the context tokens
# $p(x_{i+1}) = q(x_{i+1}|x_0, x_1, ..., x_i)$

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"t = {t}, context = {context}, target = {target}")
# Out:
# t = 0, context = tensor([18]), target = 47
# t = 1, context = tensor([18, 47]), target = 56
# t = 2, context = tensor([18, 47, 56]), target = 57
# t = 3, context = tensor([18, 47, 56, 57]), target = 58
# t = 4, context = tensor([18, 47, 56, 57, 58]), target = 1
# t = 5, context = tensor([18, 47, 56, 57, 58,  1]), target = 15
# t = 6, context = tensor([18, 47, 56, 57, 58,  1, 15]), target = 47
# t = 7, context = tensor([18, 47, 56, 57, 58,  1, 15, 47]), target = 58
# t = 8, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58]), target = 47
# t = 9, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47]), target = 64
# t = 10, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64]), target = 43
# t = 11, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43]), target = 52
# t = 12, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52]), target = 10
# t = 13, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10]), target = 0
# t = 14, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0]), target = 14
# t = 15, context = tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14]), target = 43

# %% [markdown]
# ## Creating Batches
#
# ##### Batch Size is the number of batches per example
#
# ##### Block size is the maximum context length/window for predicting

# %%
torch.manual_seed(1337)
batch_size = 4
block_size = 8

# %%
def get_batch(split):
    data = train_data if split == "train" else val_data

    ix = torch.randint(len(data) - block_size, (batch_size,))

    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])

    return x, y

# %%
xb, yb = get_batch("train")
xb.shape, yb.shape
# Out:
# (torch.Size([4, 8]), torch.Size([4, 8]))

# %%
xb, yb
# Out:
# (tensor([[53, 61, 57, 10,  0, 20, 43,  1],
#          [39, 41, 43, 42,  1, 58, 46, 43],
#          [52, 41, 43,  8,  0,  0, 24, 17],
#          [26, 33, 31, 10,  0, 25, 53, 57]]),
#  tensor([[61, 57, 10,  0, 20, 43,  1, 58],
#          [41, 43, 42,  1, 58, 46, 43,  1],
#          [41, 43,  8,  0,  0, 24, 17, 27],
#          [33, 31, 10,  0, 25, 53, 57, 58]]))

# %%
for b in range(batch_size):
    for t in range(block_size):
        context = xb[b, :t+1]
        target = yb[b, t]
        print(f"Input is {context}, target is {target}")
# Out:
# Input is tensor([53]), target is 61
# Input is tensor([53, 61]), target is 57
# Input is tensor([53, 61, 57]), target is 10
# Input is tensor([53, 61, 57, 10]), target is 0
# Input is tensor([53, 61, 57, 10,  0]), target is 20
# Input is tensor([53, 61, 57, 10,  0, 20]), target is 43
# Input is tensor([53, 61, 57, 10,  0, 20, 43]), target is 1
# Input is tensor([53, 61, 57, 10,  0, 20, 43,  1]), target is 58
# Input is tensor([39]), target is 41
# Input is tensor([39, 41]), target is 43
# Input is tensor([39, 41, 43]), target is 42
# Input is tensor([39, 41, 43, 42]), target is 1
# Input is tensor([39, 41, 43, 42,  1]), target is 58
# Input is tensor([39, 41, 43, 42,  1, 58]), target is 46
# Input is tensor([39, 41, 43, 42,  1, 58, 46]), target is 43
# Input is tensor([39, 41, 43, 42,  1, 58, 46, 43]), target is 1
# Input is tensor([52]), target is 41
# Input is tensor([52, 41]), target is 43
# Input is tensor([52, 41, 43]), target is 8
# Input is tensor([52, 41, 43,  8]), target is 0
# Input is tensor([52, 41, 43,  8,  0]), target is 0
# Input is tensor([52, 41, 43,  8,  0,  0]), target is 24
# Input is tensor([52, 41, 43,  8,  0,  0, 24]), target is 17
# Input is tensor([52, 41, 43,  8,  0,  0, 24, 17]), target is 27
# Input is tensor([26]), target is 33
# Input is tensor([26, 33]), target is 31
# Input is tensor([26, 33, 31]), target is 10
# Input is tensor([26, 33, 31, 10]), target is 0
# Input is tensor([26, 33, 31, 10,  0]), target is 25
# Input is tensor([26, 33, 31, 10,  0, 25]), target is 53
# Input is tensor([26, 33, 31, 10,  0, 25, 53]), target is 57
# Input is tensor([26, 33, 31, 10,  0, 25, 53, 57]), target is 58

# %% [markdown]
# ## Implementing the Bi-gram model

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

# %%
class BigramLanguageModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table = nn.Embedding(
            vocab_size,
            vocab_size
        )

    def forward(self, idx, targets=None):
        logits = self.token_embedding_table(idx)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)

            targets = targets.view(B*T)

            loss = F.cross_entropy(logits, targets)

        return logits, loss
    
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            logits, loss = self(idx)
            logits = logits[:, -1,:]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx
    

model = BigramLanguageModel(vocab_size)
logits, loss = model(xb, yb)
logits.shape, loss
# Out:
# (torch.Size([32, 65]), tensor(4.9670, grad_fn=<NllLossBackward0>))

# %%
encoded = model.generate(idx=torch.zeros((1,1), dtype=torch.long), max_new_tokens=100)[0].tolist()
decoded = decode(encoded)
decoded
# Out:
# '\nSKIcLT;AcELMoTbvZv C?nq-QE33:CJqkOKH-q;:la!oiywkHjgChzbQ?u!3bLIgwevmyFJGUGp\nwnYWmnxKWWev-tDqXErVKLgJ'

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

# %%
batch_steps = 32

for steps in range(10000):
    xb, yb = get_batch("train")

    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

    print(f"At {steps} step, the loss is: {loss.item()}")
# Out:
# At 0 step, the loss is: 4.45281457901001
# At 1 step, the loss is: 4.821342945098877
# At 2 step, the loss is: 4.780389785766602
# At 3 step, the loss is: 4.539166450500488
# At 4 step, the loss is: 4.395447254180908
# At 5 step, the loss is: 4.530900001525879
# At 6 step, the loss is: 4.790666103363037
# At 7 step, the loss is: 4.204006195068359
# At 8 step, the loss is: 4.515846252441406
# At 9 step, the loss is: 4.532397747039795
# At 10 step, the loss is: 4.280624866485596
# At 11 step, the loss is: 4.683449745178223
# At 12 step, the loss is: 4.556112766265869
# At 13 step, the loss is: 4.445948123931885
# At 14 step, the loss is: 4.601198673248291
# At 15 step, the loss is: 4.653167247772217
# At 16 step, the loss is: 4.711243152618408
# At 17 step, the loss is: 4.617818832397461
# At 18 step, the loss is: 4.65828800201416
# At 19 step, the loss is: 4.478277206420898
# At 20 step, the loss is: 4.747836112976074
# At 21 step, the loss is: 4.626686096191406
# At 22 step, the loss is: 4.774348735809326
# At 23 step, the loss is: 4.675390720367432
# At 24 step, the loss is: 4.968478679656982
# At 25 step, the loss is: 4.91865348815918
# At 26 step, the loss is: 4.77951192855835
# At 27 step, the loss is: 4.960871696472168
# At 28 step, the loss is: 4.603867053985596
# At 29 step, the loss is: 4.62551736831665
# At 30 step, the loss is: 4.713192462921143
# At 31 step, the loss is: 4.35186767578125
# At 32 step, the loss is: 4.516844749450684
# At 33 step, the loss is: 4.515660762786865
# At 34 step, the loss is: 4.650681018829346
# At 35 step, the loss is: 4.578446388244629
# At 36 step, the loss is: 4.564572334289551
# At 37 step, the loss is: 4.607131481170654
# At 38 step, the loss is: 4.6403727531433105
# At 39 step, the loss is: 4.718516826629639
# At 40 step, the loss is: 4.572843074798584
# At 41 step, the loss is: 4.220231056213379
# At 42 step, the loss is: 4.625688552856445
# At 43 step, the loss is: 4.338308811187744
# At 44 step, the loss is: 4.742562294006348
# At 45 step, the loss is: 4.745887279510498
# At 46 step, the loss is: 4.410500526428223
# At 47 step, the loss is: 4.849808216094971
# At 48 step, the loss is: 4.55836820602417
# At 49 step, the loss is: 4.658413410186768
# At 50 step, the loss is: 4.632462024688721
# At 51 step, the loss is: 4.524863243103027
# At 52 step, the loss is: 4.634603977203369
# At 53 step, the loss is: 4.781390190124512
# At 54 step, the loss is: 4.7796173095703125
# At 55 step, the loss is: 4.994631290435791
# At 56 step, the loss is: 4.610105037689209
# At 57 step, the loss is: 4.65380334854126
# At 58 step, the loss is: 4.606247901916504
# At 59 step, the loss is: 4.156179428100586
# At 60 step, the loss is: 4.5280680656433105
# At 61 step, the loss is: 4.68150520324707
# At 62 step, the loss is: 4.600943088531494
# At 63 step, the loss is: 4.8506760597229
# At 64 step, the loss is: 4.608373165130615
# At 65 step, the loss is: 4.951745986938477
# At 66 step, the loss is: 4.472369194030762
# At 67 step, the loss is: 4.582716464996338
# At 68 step, the loss is: 4.542469024658203
# At 69 step, the loss is: 4.597652912139893
# At 70 step, the loss is: 4.647308349609375
# At 71 step, the loss is: 4.56282377243042
# At 72 step, the loss is: 4.338494777679443
# At 73 step, the loss is: 4.784048080444336
# At 74 step, the loss is: 4.526749134063721
# At 75 step, the loss is: 4.597351551055908
# At 76 step, the loss is: 4.7935471534729
# At 77 step, the loss is: 4.736539840698242
# At 78 step, the loss is: 4.548863887786865
# At 79 step, the loss is: 4.887362957000732
# At 80 step, the loss is: 4.476783752441406
# At 81 step, the loss is: 4.8400187492370605
# At 82 step, the loss is: 4.3570027351379395
# At 83 step, the loss is: 4.398715019226074
# At 84 step, the loss is: 4.435943126678467
# At 85 step, the loss is: 4.755316734313965
# At 86 step, the loss is: 4.770036697387695
# At 87 step, the loss is: 4.656803131103516
# At 88 step, the loss is: 4.446899890899658
# At 89 step, the loss is: 4.285855293273926
# At 90 step, the loss is: 4.628343105316162
# At 91 step, the loss is: 4.348030090332031
# At 92 step, the loss is: 4.3315348625183105
# At 93 step, the loss is: 4.474295139312744
# At 94 step, the loss is: 4.14387845993042
# At 95 step, the loss is: 4.528705596923828
# At 96 step, the loss is: 4.582681179046631
# At 97 step, the loss is: 4.834095001220703
# At 98 step, the loss is: 4.7434892654418945
# At 99 step, the loss is: 4.626749038696289
# At 100 step, the loss is: 4.694116115570068
# At 101 step, the loss is: 4.561563014984131
# At 102 step, the loss is: 4.721827030181885
# At 103 step, the loss is: 4.651028633117676
# At 104 step, the loss is: 4.443182945251465
# At 105 step, the loss is: 4.560858726501465
# At 106 step, the loss is: 4.296392440795898
# At 107 step, the loss is: 4.820015907287598
# At 108 step, the loss is: 4.441107749938965
# At 109 step, the loss is: 4.30765438079834
# At 110 step, the loss is: 4.63958740234375
# At 111 step, the loss is: 4.237861633300781
# At 112 step, the loss is: 4.532157897949219
# At 113 step, the loss is: 4.534596920013428
# At 114 step, the loss is: 4.599356174468994
# At 115 step, the loss is: 4.4066481590271
# At 116 step, the loss is: 4.465184211730957
# At 117 step, the loss is: 4.574182033538818
# At 118 step, the loss is: 4.5905961990356445
# At 119 step, the loss is: 4.507106304168701
# At 120 step, the loss is: 4.60894250869751
# At 121 step, the loss is: 4.420614719390869
# At 122 step, the loss is: 4.48836612701416
# At 123 step, the loss is: 4.523460865020752
# At 124 step, the loss is: 4.846184730529785
# At 125 step, the loss is: 4.509521961212158
# At 126 step, the loss is: 4.5447187423706055
# At 127 step, the loss is: 4.522442817687988
# At 128 step, the loss is: 4.251589775085449
# At 129 step, the loss is: 4.18140983581543
# At 130 step, the loss is: 4.616690635681152
# At 131 step, the loss is: 4.579940319061279
# At 132 step, the loss is: 4.57371711730957
# At 133 step, the loss is: 4.460494041442871
# At 134 step, the loss is: 4.536960601806641
# At 135 step, the loss is: 4.829518795013428
# At 136 step, the loss is: 4.483044624328613
# At 137 step, the loss is: 4.494933605194092
# At 138 step, the loss is: 4.528141975402832
# At 139 step, the loss is: 4.8041582107543945
# At 140 step, the loss is: 4.3848795890808105
# At 141 step, the loss is: 4.7201995849609375
# At 142 step, the loss is: 4.499105930328369
# At 143 step, the loss is: 4.683558464050293
# At 144 step, the loss is: 4.279937744140625
# At 145 step, the loss is: 4.549637794494629
# At 146 step, the loss is: 4.174266338348389
# At 147 step, the loss is: 4.492663383483887
# At 148 step, the loss is: 4.672027587890625
# At 149 step, the loss is: 4.615680694580078
# At 150 step, the loss is: 4.698951721191406
# At 151 step, the loss is: 4.58285665512085
# At 152 step, the loss is: 4.666188716888428
# At 153 step, the loss is: 4.6817545890808105
# At 154 step, the loss is: 4.626163959503174
# At 155 step, the loss is: 4.922502040863037
# At 156 step, the loss is: 4.628499507904053
# At 157 step, the loss is: 4.794524192810059
# At 158 step, the loss is: 4.472846984863281
# At 159 step, the loss is: 4.484023094177246
# At 160 step, the loss is: 4.700040817260742
# At 161 step, the loss is: 4.4798173904418945
# At 162 step, the loss is: 4.461265563964844
# At 163 step, the loss is: 4.242823600769043
# At 164 step, the loss is: 4.451237201690674
# At 165 step, the loss is: 4.727897644042969
# At 166 step, the loss is: 4.560039043426514
# At 167 step, the loss is: 4.129143714904785
# At 168 step, the loss is: 4.490085124969482
# At 169 step, the loss is: 4.412920951843262
# At 170 step, the loss is: 4.526814937591553
# At 171 step, the loss is: 4.826533317565918
# At 172 step, the loss is: 4.385349750518799
# At 173 step, the loss is: 4.412139415740967
# At 174 step, the loss is: 4.759670257568359
# At 175 step, the loss is: 4.5922064781188965
# At 176 step, the loss is: 4.2065110206604
# At 177 step, the loss is: 4.321210861206055
# At 178 step, the loss is: 4.433936595916748
# At 179 step, the loss is: 4.597726821899414
# At 180 step, the loss is: 4.254391193389893
# At 181 step, the loss is: 4.337192535400391
# At 182 step, the loss is: 4.370718479156494
# At 183 step, the loss is: 4.746391296386719
# At 184 step, the loss is: 4.47901725769043
# At 185 step, the loss is: 4.467772960662842
# At 186 step, the loss is: 4.461221694946289
# At 187 step, the loss is: 4.8530964851379395
# At 188 step, the loss is: 4.671846389770508
# At 189 step, the loss is: 4.328699111938477
# At 190 step, the loss is: 4.43079137802124
# At 191 step, the loss is: 4.282328128814697
# At 192 step, the loss is: 4.504669189453125
# At 193 step, the loss is: 4.597085952758789
# At 194 step, the loss is: 4.782394886016846
# At 195 step, the loss is: 4.339335918426514
# At 196 step, the loss is: 4.422094821929932
# At 197 step, the loss is: 4.290975570678711
# At 198 step, the loss is: 4.457687854766846
# At 199 step, the loss is: 4.335484027862549
# At 200 step, the loss is: 4.518490791320801
# At 201 step, the loss is: 4.280434608459473
# At 202 step, the loss is: 4.4391279220581055
# At 203 step, the loss is: 4.481469631195068
# At 204 step, the loss is: 4.692748546600342
# At 205 step, the loss is: 4.447632312774658
# At 206 step, the loss is: 4.565242767333984
# At 207 step, the loss is: 4.435103416442871
# At 208 step, the loss is: 4.326399326324463
# At 209 step, the loss is: 4.71599006652832
# At 210 step, the loss is: 4.502257823944092
# At 211 step, the loss is: 4.392694473266602
# At 212 step, the loss is: 4.461632251739502
# At 213 step, the loss is: 4.5417609214782715
# At 214 step, the loss is: 4.276937961578369
# At 215 step, the loss is: 4.444225311279297
# At 216 step, the loss is: 4.481851100921631
# At 217 step, the loss is: 4.478224277496338
# At 218 step, the loss is: 4.825410842895508
# At 219 step, the loss is: 4.448566436767578
# At 220 step, the loss is: 4.4982590675354
# At 221 step, the loss is: 4.336347579956055
# At 222 step, the loss is: 4.595817565917969
# At 223 step, the loss is: 4.358344078063965
# At 224 step, the loss is: 4.313930988311768
# At 225 step, the loss is: 4.3823771476745605
# At 226 step, the loss is: 4.254398822784424
# At 227 step, the loss is: 4.462367534637451
# At 228 step, the loss is: 4.566582202911377
# At 229 step, the loss is: 4.473838806152344
# At 230 step, the loss is: 4.6089982986450195
# At 231 step, the loss is: 4.395918369293213
# At 232 step, the loss is: 4.6066813468933105
# At 233 step, the loss is: 4.582101345062256
# At 234 step, the loss is: 4.26489782333374
# At 235 step, the loss is: 4.1220855712890625
# At 236 step, the loss is: 4.4342193603515625
# At 237 step, the loss is: 4.417247772216797
# At 238 step, the loss is: 4.478479862213135
# At 239 step, the loss is: 4.683812618255615
# At 240 step, the loss is: 4.441877841949463
# At 241 step, the loss is: 4.391701698303223
# At 242 step, the loss is: 4.42088508605957
# At 243 step, the loss is: 4.797797203063965
# At 244 step, the loss is: 4.307276725769043
# At 245 step, the loss is: 4.850463390350342
# At 246 step, the loss is: 4.647733211517334
# At 247 step, the loss is: 4.597545146942139
# At 248 step, the loss is: 4.569458484649658
# At 249 step, the loss is: 4.668366432189941
# At 250 step, the loss is: 4.275259017944336
# At 251 step, the loss is: 4.411838531494141
# At 252 step, the loss is: 4.4035420417785645
# At 253 step, the loss is: 4.461917400360107
# At 254 step, the loss is: 4.636274337768555
# At 255 step, the loss is: 4.430695533752441
# At 256 step, the loss is: 4.344335556030273
# At 257 step, the loss is: 4.582920551300049
# At 258 step, the loss is: 4.512232780456543
# At 259 step, the loss is: 4.47598123550415
# At 260 step, the loss is: 4.371065139770508
# At 261 step, the loss is: 4.695878028869629
# At 262 step, the loss is: 4.605371475219727
# At 263 step, the loss is: 4.560330867767334
# At 264 step, the loss is: 4.649827003479004
# At 265 step, the loss is: 4.417840480804443
# At 266 step, the loss is: 4.478553771972656
# At 267 step, the loss is: 4.440313816070557
# At 268 step, the loss is: 4.324344635009766
# At 269 step, the loss is: 4.224685192108154
# At 270 step, the loss is: 4.6292500495910645
# At 271 step, the loss is: 4.2549848556518555
# At 272 step, the loss is: 4.41343355178833
# At 273 step, the loss is: 4.248782634735107
# At 274 step, the loss is: 4.620176792144775
# At 275 step, the loss is: 4.689558506011963
# At 276 step, the loss is: 4.443706512451172
# At 277 step, the loss is: 4.806267261505127
# At 278 step, the loss is: 4.532401084899902
# At 279 step, the loss is: 4.462050437927246
# At 280 step, the loss is: 4.353837490081787
# At 281 step, the loss is: 4.515978813171387
# At 282 step, the loss is: 4.371074199676514
# At 283 step, the loss is: 4.385849475860596
# At 284 step, the loss is: 4.428378582000732
# At 285 step, the loss is: 4.3523359298706055
# At 286 step, the loss is: 4.0713090896606445
# At 287 step, the loss is: 4.207291126251221
# At 288 step, the loss is: 4.3769450187683105
# At 289 step, the loss is: 4.50040864944458
# At 290 step, the loss is: 4.629033088684082
# At 291 step, the loss is: 4.450775146484375
# At 292 step, the loss is: 4.279748916625977
# At 293 step, the loss is: 4.125030517578125
# At 294 step, the loss is: 4.559963703155518
# At 295 step, the loss is: 4.526997089385986
# At 296 step, the loss is: 4.261072635650635
# At 297 step, the loss is: 4.410236835479736
# At 298 step, the loss is: 4.2272047996521
# At 299 step, the loss is: 4.282724857330322
# At 300 step, the loss is: 4.7098469734191895
# At 301 step, the loss is: 4.578836917877197
# At 302 step, the loss is: 4.602513790130615
# At 303 step, the loss is: 4.390565872192383
# At 304 step, the loss is: 4.276495456695557
# At 305 step, the loss is: 4.413309574127197
# At 306 step, the loss is: 4.641274452209473
# At 307 step, the loss is: 4.55517578125
# At 308 step, the loss is: 4.601055145263672
# At 309 step, the loss is: 4.410754203796387
# At 310 step, the loss is: 4.431385517120361
# At 311 step, the loss is: 4.176278591156006
# At 312 step, the loss is: 4.302969455718994
# At 313 step, the loss is: 4.377257823944092
# At 314 step, the loss is: 4.231079578399658
# At 315 step, the loss is: 4.22533655166626
# At 316 step, the loss is: 4.233978271484375
# At 317 step, the loss is: 4.243401527404785
# At 318 step, the loss is: 4.470188617706299
# At 319 step, the loss is: 4.584599018096924
# At 320 step, the loss is: 4.300397872924805
# At 321 step, the loss is: 4.1323418617248535
# At 322 step, the loss is: 4.259017467498779
# At 323 step, the loss is: 4.237486839294434
# At 324 step, the loss is: 4.640356540679932
# At 325 step, the loss is: 4.241939544677734
# At 326 step, the loss is: 4.406085014343262
# At 327 step, the loss is: 4.327001571655273
# At 328 step, the loss is: 4.476032733917236
# At 329 step, the loss is: 4.343387603759766
# At 330 step, the loss is: 4.506787300109863
# At 331 step, the loss is: 4.227138519287109
# At 332 step, the loss is: 4.643243312835693
# At 333 step, the loss is: 4.284397602081299
# At 334 step, the loss is: 4.407649517059326
# At 335 step, the loss is: 4.809402942657471
# At 336 step, the loss is: 4.6261372566223145
# At 337 step, the loss is: 4.410611629486084
# At 338 step, the loss is: 4.3574910163879395
# At 339 step, the loss is: 4.320088863372803
# At 340 step, the loss is: 4.210089206695557
# At 341 step, the loss is: 4.347287654876709
# At 342 step, the loss is: 4.176020622253418
# At 343 step, the loss is: 4.277773857116699
# At 344 step, the loss is: 4.20712423324585
# At 345 step, the loss is: 4.667814254760742
# At 346 step, the loss is: 4.390347003936768
# At 347 step, the loss is: 4.363123416900635
# At 348 step, the loss is: 4.591930866241455
# At 349 step, the loss is: 4.40244722366333
# At 350 step, the loss is: 4.296482563018799
# At 351 step, the loss is: 4.294741630554199
# At 352 step, the loss is: 4.295054912567139
# At 353 step, the loss is: 4.4608683586120605
# At 354 step, the loss is: 4.567399024963379
# At 355 step, the loss is: 4.541021823883057
# At 356 step, the loss is: 4.6995463371276855
# At 357 step, the loss is: 4.459121227264404
# At 358 step, the loss is: 4.431136608123779
# At 359 step, the loss is: 4.758502006530762
# At 360 step, the loss is: 4.30751371383667
# At 361 step, the loss is: 4.288467884063721
# At 362 step, the loss is: 4.508694171905518
# At 363 step, the loss is: 4.556395530700684
# At 364 step, the loss is: 4.580581188201904
# At 365 step, the loss is: 4.458000659942627
# At 366 step, the loss is: 4.437260150909424
# At 367 step, the loss is: 4.236012935638428
# At 368 step, the loss is: 4.209069728851318
# At 369 step, the loss is: 4.589264869689941
# At 370 step, the loss is: 4.336971282958984
# At 371 step, the loss is: 4.60421085357666
# At 372 step, the loss is: 4.506829261779785
# At 373 step, the loss is: 4.651472091674805
# At 374 step, the loss is: 4.273886680603027
# At 375 step, the loss is: 4.4149980545043945
# At 376 step, the loss is: 4.380160331726074
# At 377 step, the loss is: 4.447877407073975
# At 378 step, the loss is: 4.4659342765808105
# At 379 step, the loss is: 4.390262603759766
# At 380 step, the loss is: 4.56696891784668
# At 381 step, the loss is: 4.216716289520264
# At 382 step, the loss is: 4.161299705505371
# At 383 step, the loss is: 4.273601055145264
# At 384 step, the loss is: 4.2537055015563965
# At 385 step, the loss is: 4.463080406188965
# At 386 step, the loss is: 4.600490570068359
# At 387 step, the loss is: 4.330713748931885
# At 388 step, the loss is: 4.153509616851807
# At 389 step, the loss is: 4.451406002044678
# At 390 step, the loss is: 4.340056896209717
# At 391 step, the loss is: 4.7516984939575195
# At 392 step, the loss is: 4.295109272003174
# At 393 step, the loss is: 4.428128242492676
# At 394 step, the loss is: 4.398184776306152
# At 395 step, the loss is: 4.407253265380859
# At 396 step, the loss is: 4.428445816040039
# At 397 step, the loss is: 4.213848114013672
# At 398 step, the loss is: 4.533597946166992
# At 399 step, the loss is: 4.3393425941467285
# At 400 step, the loss is: 4.432809352874756
# At 401 step, the loss is: 4.480983734130859
# At 402 step, the loss is: 4.310853958129883
# At 403 step, the loss is: 4.285784721374512
# At 404 step, the loss is: 4.319232940673828
# At 405 step, the loss is: 4.303953170776367
# At 406 step, the loss is: 4.450418949127197
# At 407 step, the loss is: 4.456894397735596
# At 408 step, the loss is: 4.2682623863220215
# At 409 step, the loss is: 4.315530300140381
# At 410 step, the loss is: 4.219103813171387
# At 411 step, the loss is: 4.333285808563232
# At 412 step, the loss is: 4.30767822265625
# At 413 step, the loss is: 4.391778945922852
# At 414 step, the loss is: 4.115069389343262
# At 415 step, the loss is: 4.443294525146484
# At 416 step, the loss is: 4.177096843719482
# At 417 step, the loss is: 4.1606340408325195
# At 418 step, the loss is: 4.415130615234375
# At 419 step, the loss is: 4.577779293060303
# At 420 step, the loss is: 4.439057350158691
# At 421 step, the loss is: 4.189779758453369
# At 422 step, the loss is: 4.265552520751953
# At 423 step, the loss is: 4.61379337310791
# At 424 step, the loss is: 4.133505344390869
# At 425 step, the loss is: 4.3536787033081055
# At 426 step, the loss is: 4.255671977996826
# At 427 step, the loss is: 4.3524675369262695
# At 428 step, the loss is: 4.312803268432617
# At 429 step, the loss is: 4.115590572357178
# At 430 step, the loss is: 4.432973861694336
# At 431 step, the loss is: 4.558271884918213
# At 432 step, the loss is: 4.256575584411621
# At 433 step, the loss is: 4.333042144775391
# At 434 step, the loss is: 4.54087495803833
# At 435 step, the loss is: 4.572568416595459
# At 436 step, the loss is: 4.347098350524902
# At 437 step, the loss is: 4.140197277069092
# At 438 step, the loss is: 4.302229404449463
# At 439 step, the loss is: 4.493628978729248
# At 440 step, the loss is: 4.064479827880859
# At 441 step, the loss is: 4.4373016357421875
# At 442 step, the loss is: 4.381062984466553
# At 443 step, the loss is: 4.186947822570801
# At 444 step, the loss is: 4.3612141609191895
# At 445 step, the loss is: 4.093722820281982
# At 446 step, the loss is: 4.157318115234375
# At 447 step, the loss is: 4.0235276222229
# At 448 step, the loss is: 4.299410343170166
# At 449 step, the loss is: 4.227294921875
# At 450 step, the loss is: 4.42871618270874
# At 451 step, the loss is: 4.196915149688721
# At 452 step, the loss is: 4.190330982208252
# At 453 step, the loss is: 4.222702503204346
# At 454 step, the loss is: 4.336264133453369
# At 455 step, the loss is: 4.2585673332214355
# At 456 step, the loss is: 4.117691993713379
# At 457 step, the loss is: 4.291393280029297
# At 458 step, the loss is: 4.580679416656494
# At 459 step, the loss is: 4.632960796356201
# At 460 step, the loss is: 4.343341827392578
# At 461 step, the loss is: 4.4728779792785645
# At 462 step, the loss is: 4.319188117980957
# At 463 step, the loss is: 4.197287082672119
# At 464 step, the loss is: 4.309084415435791
# At 465 step, the loss is: 4.165969371795654
# At 466 step, the loss is: 4.082627773284912
# At 467 step, the loss is: 4.390006065368652
# At 468 step, the loss is: 4.492396354675293
# At 469 step, the loss is: 4.633857727050781
# At 470 step, the loss is: 4.014660835266113
# At 471 step, the loss is: 4.205047607421875
# At 472 step, the loss is: 4.419815540313721
# At 473 step, the loss is: 3.907191276550293
# At 474 step, the loss is: 4.557756423950195
# At 475 step, the loss is: 4.184520244598389
# At 476 step, the loss is: 4.236299514770508
# At 477 step, the loss is: 4.481261730194092
# At 478 step, the loss is: 4.383927822113037
# At 479 step, the loss is: 4.198050498962402
# At 480 step, the loss is: 3.920309543609619
# At 481 step, the loss is: 4.566431522369385
# At 482 step, the loss is: 4.537909507751465
# At 483 step, the loss is: 3.9860239028930664
# At 484 step, the loss is: 4.06343412399292
# At 485 step, the loss is: 4.410910606384277
# At 486 step, the loss is: 4.267185688018799
# At 487 step, the loss is: 4.5275726318359375
# At 488 step, the loss is: 4.387355327606201
# At 489 step, the loss is: 4.409377098083496
# At 490 step, the loss is: 4.33849573135376
# At 491 step, the loss is: 4.507884502410889
# At 492 step, the loss is: 4.412450790405273
# At 493 step, the loss is: 4.490097522735596
# At 494 step, the loss is: 4.114367485046387
# At 495 step, the loss is: 4.349867820739746
# At 496 step, the loss is: 4.113760471343994
# At 497 step, the loss is: 4.00396203994751
# At 498 step, the loss is: 4.00370979309082
# At 499 step, the loss is: 4.286713123321533
# At 500 step, the loss is: 4.325082302093506
# At 501 step, the loss is: 4.073967456817627
# At 502 step, the loss is: 4.545549392700195
# At 503 step, the loss is: 4.391611576080322
# At 504 step, the loss is: 3.952972412109375
# At 505 step, the loss is: 4.351327419281006
# At 506 step, the loss is: 4.39874792098999
# At 507 step, the loss is: 4.326823711395264
# At 508 step, the loss is: 4.377006530761719
# At 509 step, the loss is: 4.587865352630615
# At 510 step, the loss is: 4.0255513191223145
# At 511 step, the loss is: 4.518908500671387
# At 512 step, the loss is: 4.376979827880859
# At 513 step, the loss is: 4.314439296722412
# At 514 step, the loss is: 4.171267986297607
# At 515 step, the loss is: 4.415980339050293
# At 516 step, the loss is: 4.152787208557129
# At 517 step, the loss is: 4.635037422180176
# At 518 step, the loss is: 4.15108585357666
# At 519 step, the loss is: 4.7429609298706055
# At 520 step, the loss is: 4.447672367095947
# At 521 step, the loss is: 4.37393856048584
# At 522 step, the loss is: 4.437422275543213
# At 523 step, the loss is: 4.280533790588379
# At 524 step, the loss is: 4.085627555847168
# At 525 step, the loss is: 4.203494548797607
# At 526 step, the loss is: 4.755903244018555
# At 527 step, the loss is: 4.271147727966309
# At 528 step, the loss is: 4.4086833000183105
# At 529 step, the loss is: 4.161911964416504
# At 530 step, the loss is: 4.435344696044922
# At 531 step, the loss is: 4.133998870849609
# At 532 step, the loss is: 4.3089518547058105
# At 533 step, the loss is: 4.154135704040527
# At 534 step, the loss is: 4.135756015777588
# At 535 step, the loss is: 4.3816423416137695
# At 536 step, the loss is: 4.0663933753967285
# At 537 step, the loss is: 4.459346771240234
# At 538 step, the loss is: 4.248080253601074
# At 539 step, the loss is: 4.136728763580322
# At 540 step, the loss is: 3.9187238216400146
# At 541 step, the loss is: 4.428403377532959
# At 542 step, the loss is: 4.529180526733398
# At 543 step, the loss is: 4.0318989753723145
# At 544 step, the loss is: 4.250912189483643
# At 545 step, the loss is: 4.404897689819336
# At 546 step, the loss is: 3.961358070373535
# At 547 step, the loss is: 4.468667984008789
# At 548 step, the loss is: 4.304657459259033
# At 549 step, the loss is: 4.163049697875977
# At 550 step, the loss is: 4.626946449279785
# At 551 step, the loss is: 4.159380912780762
# At 552 step, the loss is: 4.085890769958496
# At 553 step, the loss is: 4.071080207824707
# At 554 step, the loss is: 4.585564613342285
# At 555 step, the loss is: 4.227394104003906
# At 556 step, the loss is: 4.294747829437256
# At 557 step, the loss is: 4.193331718444824
# At 558 step, the loss is: 4.178501605987549
# At 559 step, the loss is: 4.268283367156982
# At 560 step, the loss is: 4.2044501304626465
# At 561 step, the loss is: 4.129401206970215
# At 562 step, the loss is: 4.118832111358643
# At 563 step, the loss is: 4.619067668914795
# At 564 step, the loss is: 4.177402973175049
# At 565 step, the loss is: 4.35637903213501
# At 566 step, the loss is: 4.327013969421387
# At 567 step, the loss is: 4.260639190673828
# At 568 step, the loss is: 4.382789134979248
# At 569 step, the loss is: 4.341748237609863
# At 570 step, the loss is: 4.548155307769775
# At 571 step, the loss is: 4.167237758636475
# At 572 step, the loss is: 4.110138893127441
# At 573 step, the loss is: 4.393787860870361
# At 574 step, the loss is: 4.291845798492432
# At 575 step, the loss is: 4.118916988372803
# At 576 step, the loss is: 4.088320255279541
# At 577 step, the loss is: 4.498937606811523
# At 578 step, the loss is: 3.8771378993988037
# At 579 step, the loss is: 4.152629375457764
# At 580 step, the loss is: 4.165435791015625
# At 581 step, the loss is: 4.267865180969238
# At 582 step, the loss is: 4.071938991546631
# At 583 step, the loss is: 4.252634525299072
# At 584 step, the loss is: 4.519763946533203
# At 585 step, the loss is: 4.239404201507568
# At 586 step, the loss is: 4.245797634124756
# At 587 step, the loss is: 4.092309951782227
# At 588 step, the loss is: 4.37489652633667
# At 589 step, the loss is: 4.287037372589111
# At 590 step, the loss is: 4.462490081787109
# At 591 step, the loss is: 4.172911643981934
# At 592 step, the loss is: 4.172062397003174
# At 593 step, the loss is: 4.113534927368164
# At 594 step, the loss is: 4.387053966522217
# At 595 step, the loss is: 4.061163425445557
# At 596 step, the loss is: 4.227381229400635
# At 597 step, the loss is: 4.481094837188721
# At 598 step, the loss is: 4.106686115264893
# At 599 step, the loss is: 4.148899078369141
# At 600 step, the loss is: 4.260626316070557
# At 601 step, the loss is: 4.147613525390625
# At 602 step, the loss is: 4.531140327453613
# At 603 step, the loss is: 3.774449110031128
# At 604 step, the loss is: 4.326571464538574
# At 605 step, the loss is: 4.186748027801514
# At 606 step, the loss is: 4.5167341232299805
# At 607 step, the loss is: 4.290935516357422
# At 608 step, the loss is: 4.237895965576172
# At 609 step, the loss is: 4.194476127624512
# At 610 step, the loss is: 4.448990821838379
# At 611 step, the loss is: 4.4043731689453125
# At 612 step, the loss is: 4.5341410636901855
# At 613 step, the loss is: 4.046614170074463
# At 614 step, the loss is: 4.14474630355835
# At 615 step, the loss is: 4.381643295288086
# At 616 step, the loss is: 4.22743558883667
# At 617 step, the loss is: 4.069321632385254
# At 618 step, the loss is: 4.2002034187316895
# At 619 step, the loss is: 4.273301124572754
# At 620 step, the loss is: 4.175171852111816
# At 621 step, the loss is: 4.308529376983643
# At 622 step, the loss is: 4.524865627288818
# At 623 step, the loss is: 4.0168633460998535
# At 624 step, the loss is: 4.381804466247559
# At 625 step, the loss is: 3.9657416343688965
# At 626 step, the loss is: 4.189272880554199
# At 627 step, the loss is: 4.0245232582092285
# At 628 step, the loss is: 4.246973514556885
# At 629 step, the loss is: 4.233524799346924
# At 630 step, the loss is: 4.174498558044434
# At 631 step, the loss is: 4.177784442901611
# At 632 step, the loss is: 4.079751014709473
# At 633 step, the loss is: 4.040775299072266
# At 634 step, the loss is: 4.07780122756958
# At 635 step, the loss is: 3.9163339138031006
# At 636 step, the loss is: 4.325362205505371
# At 637 step, the loss is: 4.314528465270996
# At 638 step, the loss is: 4.175296306610107
# At 639 step, the loss is: 4.193195819854736
# At 640 step, the loss is: 4.117076873779297
# At 641 step, the loss is: 4.244106769561768
# At 642 step, the loss is: 4.332812309265137
# At 643 step, the loss is: 4.309157848358154
# At 644 step, the loss is: 4.179714202880859
# At 645 step, the loss is: 4.430230617523193
# At 646 step, the loss is: 4.326066017150879
# At 647 step, the loss is: 4.274509906768799
# At 648 step, the loss is: 3.753091335296631
# At 649 step, the loss is: 4.188501358032227
# At 650 step, the loss is: 4.179625988006592
# At 651 step, the loss is: 4.390941143035889
# At 652 step, the loss is: 4.315425872802734
# At 653 step, the loss is: 4.407959461212158
# At 654 step, the loss is: 4.272007942199707
# At 655 step, the loss is: 4.061758041381836
# At 656 step, the loss is: 4.028802394866943
# At 657 step, the loss is: 4.124660968780518
# At 658 step, the loss is: 4.137643814086914
# At 659 step, the loss is: 4.195577144622803
# At 660 step, the loss is: 4.229846000671387
# At 661 step, the loss is: 4.122990131378174
# At 662 step, the loss is: 4.358906269073486
# At 663 step, the loss is: 4.022636413574219
# At 664 step, the loss is: 4.068500995635986
# At 665 step, the loss is: 4.312242031097412
# At 666 step, the loss is: 4.256247043609619
# At 667 step, the loss is: 4.414944171905518
# At 668 step, the loss is: 4.362607002258301
# At 669 step, the loss is: 4.322264671325684
# At 670 step, the loss is: 4.358918190002441
# At 671 step, the loss is: 4.072824001312256
# At 672 step, the loss is: 4.148390293121338
# At 673 step, the loss is: 4.387141227722168
# At 674 step, the loss is: 4.264106750488281
# At 675 step, the loss is: 4.314173221588135
# At 676 step, the loss is: 4.260316848754883
# At 677 step, the loss is: 4.269042015075684
# At 678 step, the loss is: 4.043859481811523
# At 679 step, the loss is: 4.238564968109131
# At 680 step, the loss is: 4.29847526550293
# At 681 step, the loss is: 4.323227882385254
# At 682 step, the loss is: 4.02155876159668
# At 683 step, the loss is: 4.113884449005127
# At 684 step, the loss is: 4.45427131652832
# At 685 step, the loss is: 4.294547080993652
# At 686 step, the loss is: 4.083064079284668
# At 687 step, the loss is: 4.200423240661621
# At 688 step, the loss is: 4.101365089416504
# At 689 step, the loss is: 4.26206636428833
# At 690 step, the loss is: 4.251918792724609
# At 691 step, the loss is: 4.427164077758789
# At 692 step, the loss is: 4.136133670806885
# At 693 step, the loss is: 3.833101749420166
# At 694 step, the loss is: 4.429140090942383
# At 695 step, the loss is: 4.219080448150635
# At 696 step, the loss is: 4.327643394470215
# At 697 step, the loss is: 4.10565185546875
# At 698 step, the loss is: 4.07702112197876
# At 699 step, the loss is: 4.122706413269043
# At 700 step, the loss is: 4.33773946762085
# At 701 step, the loss is: 4.018129348754883
# At 702 step, the loss is: 3.9444611072540283
# At 703 step, the loss is: 4.011146545410156
# At 704 step, the loss is: 4.191064834594727
# At 705 step, the loss is: 4.441892623901367
# At 706 step, the loss is: 4.155345439910889
# At 707 step, the loss is: 4.111844539642334
# At 708 step, the loss is: 4.173037052154541
# At 709 step, the loss is: 4.431648254394531
# At 710 step, the loss is: 4.359473705291748
# At 711 step, the loss is: 4.394954204559326
# At 712 step, the loss is: 4.309408664703369
# At 713 step, the loss is: 4.427681922912598
# At 714 step, the loss is: 4.226444244384766
# At 715 step, the loss is: 3.844050168991089
# At 716 step, the loss is: 4.439791679382324
# At 717 step, the loss is: 4.418032646179199
# At 718 step, the loss is: 4.150983810424805
# At 719 step, the loss is: 4.0487565994262695
# At 720 step, the loss is: 3.736841917037964
# At 721 step, the loss is: 4.226906776428223
# At 722 step, the loss is: 4.436275005340576
# At 723 step, the loss is: 4.0434184074401855
# At 724 step, the loss is: 4.186463356018066
# At 725 step, the loss is: 4.197052001953125
# At 726 step, the loss is: 4.503328323364258
# At 727 step, the loss is: 4.111889362335205
# At 728 step, the loss is: 3.9498977661132812
# At 729 step, the loss is: 4.126508712768555
# At 730 step, the loss is: 4.1469573974609375
# At 731 step, the loss is: 4.082723617553711
# At 732 step, the loss is: 4.319714546203613
# At 733 step, the loss is: 3.821338176727295
# At 734 step, the loss is: 4.404539108276367
# At 735 step, the loss is: 4.4608869552612305
# At 736 step, the loss is: 4.075300693511963
# At 737 step, the loss is: 4.144968032836914
# At 738 step, the loss is: 4.047378063201904
# At 739 step, the loss is: 4.526110649108887
# At 740 step, the loss is: 4.009338855743408
# At 741 step, the loss is: 3.9282724857330322
# At 742 step, the loss is: 4.504386901855469
# At 743 step, the loss is: 4.30120849609375
# At 744 step, the loss is: 3.9238507747650146
# At 745 step, the loss is: 4.243509292602539
# At 746 step, the loss is: 4.2934417724609375
# At 747 step, the loss is: 4.005061149597168
# At 748 step, the loss is: 4.166021823883057
# At 749 step, the loss is: 3.9810335636138916
# At 750 step, the loss is: 4.101455211639404
# At 751 step, the loss is: 3.927048444747925
# At 752 step, the loss is: 4.051581382751465
# At 753 step, the loss is: 3.8194692134857178
# At 754 step, the loss is: 3.84826397895813
# At 755 step, the loss is: 4.064939975738525
# At 756 step, the loss is: 4.004276752471924
# At 757 step, the loss is: 3.9296231269836426
# At 758 step, the loss is: 4.063174247741699
# At 759 step, the loss is: 3.9173684120178223
# At 760 step, the loss is: 4.159204483032227
# At 761 step, the loss is: 4.296504020690918
# At 762 step, the loss is: 3.8875629901885986
# At 763 step, the loss is: 4.53769588470459
# At 764 step, the loss is: 4.001535892486572
# At 765 step, the loss is: 3.9881885051727295
# At 766 step, the loss is: 3.845216751098633
# At 767 step, the loss is: 3.9328572750091553
# At 768 step, the loss is: 4.20356559753418
# At 769 step, the loss is: 3.9725563526153564
# At 770 step, the loss is: 4.154237270355225
# At 771 step, the loss is: 4.103361129760742
# At 772 step, the loss is: 4.56058406829834
# At 773 step, the loss is: 4.074563026428223
# At 774 step, the loss is: 4.298848628997803
# At 775 step, the loss is: 4.124521732330322
# At 776 step, the loss is: 4.068337917327881
# At 777 step, the loss is: 4.230710506439209
# At 778 step, the loss is: 4.3173627853393555
# At 779 step, the loss is: 4.101078987121582
# At 780 step, the loss is: 4.054434299468994
# At 781 step, the loss is: 4.264452934265137
# At 782 step, the loss is: 4.164124488830566
# At 783 step, the loss is: 4.05305290222168
# At 784 step, the loss is: 4.079687595367432
# At 785 step, the loss is: 4.215173244476318
# At 786 step, the loss is: 4.041530132293701
# At 787 step, the loss is: 4.0694499015808105
# At 788 step, the loss is: 4.161104202270508
# At 789 step, the loss is: 4.621568202972412
# At 790 step, the loss is: 3.9437880516052246
# At 791 step, the loss is: 4.332261562347412
# At 792 step, the loss is: 4.145655632019043
# At 793 step, the loss is: 4.040940284729004
# At 794 step, the loss is: 4.2297563552856445
# At 795 step, the loss is: 3.8559231758117676
# At 796 step, the loss is: 3.7772958278656006
# At 797 step, the loss is: 4.082424640655518
# At 798 step, the loss is: 4.242941856384277
# At 799 step, the loss is: 4.194167613983154
# At 800 step, the loss is: 4.016165256500244
# At 801 step, the loss is: 4.068460941314697
# At 802 step, the loss is: 3.7822728157043457
# At 803 step, the loss is: 3.798462390899658
# At 804 step, the loss is: 4.284626483917236
# At 805 step, the loss is: 4.468010425567627
# At 806 step, the loss is: 4.076497554779053
# At 807 step, the loss is: 3.992424964904785
# At 808 step, the loss is: 4.011837959289551
# At 809 step, the loss is: 4.394278049468994
# At 810 step, the loss is: 4.23247766494751
# At 811 step, the loss is: 4.392882347106934
# At 812 step, the loss is: 4.003435134887695
# At 813 step, the loss is: 4.0627760887146
# At 814 step, the loss is: 4.035454273223877
# At 815 step, the loss is: 3.916395664215088
# At 816 step, the loss is: 4.162473201751709
# At 817 step, the loss is: 4.045651912689209
# At 818 step, the loss is: 4.325237274169922
# At 819 step, the loss is: 4.147568225860596
# At 820 step, the loss is: 3.9430813789367676
# At 821 step, the loss is: 4.223333358764648
# At 822 step, the loss is: 4.108591556549072
# At 823 step, the loss is: 4.077291011810303
# At 824 step, the loss is: 3.914583683013916
# At 825 step, the loss is: 4.077622413635254
# At 826 step, the loss is: 4.14332914352417
# At 827 step, the loss is: 3.8696823120117188
# At 828 step, the loss is: 4.2488322257995605
# At 829 step, the loss is: 3.873265266418457
# At 830 step, the loss is: 4.160091876983643
# At 831 step, the loss is: 4.152404308319092
# At 832 step, the loss is: 4.093226432800293
# At 833 step, the loss is: 4.274124622344971
# At 834 step, the loss is: 3.996326446533203
# At 835 step, the loss is: 3.988602638244629
# At 836 step, the loss is: 4.002693176269531
# At 837 step, the loss is: 4.275882244110107
# At 838 step, the loss is: 3.9555251598358154
# At 839 step, the loss is: 4.01011848449707
# At 840 step, the loss is: 4.439136505126953
# At 841 step, the loss is: 4.157988548278809
# At 842 step, the loss is: 4.0584821701049805
# At 843 step, the loss is: 3.8894453048706055
# At 844 step, the loss is: 4.072536945343018
# At 845 step, the loss is: 4.057427883148193
# At 846 step, the loss is: 3.7423667907714844
# At 847 step, the loss is: 3.91367244720459
# At 848 step, the loss is: 3.7538187503814697
# At 849 step, the loss is: 4.1973185539245605
# At 850 step, the loss is: 4.155855178833008
# At 851 step, the loss is: 3.895439863204956
# At 852 step, the loss is: 4.303856372833252
# At 853 step, the loss is: 4.4580817222595215
# At 854 step, the loss is: 4.043551921844482
# At 855 step, the loss is: 4.073382377624512
# At 856 step, the loss is: 4.132290840148926
# At 857 step, the loss is: 4.1701154708862305
# At 858 step, the loss is: 4.130396842956543
# At 859 step, the loss is: 4.044934272766113
# At 860 step, the loss is: 4.244326591491699
# At 861 step, the loss is: 4.092612266540527
# At 862 step, the loss is: 4.185356616973877
# At 863 step, the loss is: 4.141149044036865
# At 864 step, the loss is: 4.245866298675537
# At 865 step, the loss is: 4.1636857986450195
# At 866 step, the loss is: 3.919867515563965
# At 867 step, the loss is: 3.9943509101867676
# At 868 step, the loss is: 3.8783726692199707
# At 869 step, the loss is: 4.173680782318115
# At 870 step, the loss is: 4.170458793640137
# At 871 step, the loss is: 4.014641761779785
# At 872 step, the loss is: 3.897676944732666
# At 873 step, the loss is: 4.014562606811523
# At 874 step, the loss is: 4.0391316413879395
# At 875 step, the loss is: 4.162421703338623
# At 876 step, the loss is: 4.0952582359313965
# At 877 step, the loss is: 4.103771686553955
# At 878 step, the loss is: 4.327661037445068
# At 879 step, the loss is: 4.203082084655762
# At 880 step, the loss is: 4.219228744506836
# At 881 step, the loss is: 3.895960569381714
# At 882 step, the loss is: 4.039919853210449
# At 883 step, the loss is: 3.9909110069274902
# At 884 step, the loss is: 3.8042924404144287
# At 885 step, the loss is: 4.244899749755859
# At 886 step, the loss is: 4.0960822105407715
# At 887 step, the loss is: 4.329798221588135
# At 888 step, the loss is: 3.8350889682769775
# At 889 step, the loss is: 4.186136722564697
# At 890 step, the loss is: 3.898261785507202
# At 891 step, the loss is: 3.9744699001312256
# At 892 step, the loss is: 4.026429176330566
# At 893 step, the loss is: 3.9356496334075928
# At 894 step, the loss is: 4.1277055740356445
# At 895 step, the loss is: 4.080299377441406
# At 896 step, the loss is: 3.9241108894348145
# At 897 step, the loss is: 4.068617343902588
# At 898 step, the loss is: 4.534829139709473
# At 899 step, the loss is: 3.9839465618133545
# At 900 step, the loss is: 3.9853057861328125
# At 901 step, the loss is: 3.858278274536133
# At 902 step, the loss is: 3.9022908210754395
# At 903 step, the loss is: 4.29267692565918
# At 904 step, the loss is: 4.207005500793457
# At 905 step, the loss is: 4.14830207824707
# At 906 step, the loss is: 3.8779873847961426
# At 907 step, the loss is: 4.28122091293335
# At 908 step, the loss is: 4.062602996826172
# At 909 step, the loss is: 4.23939323425293
# At 910 step, the loss is: 3.8128364086151123
# At 911 step, the loss is: 4.382063865661621
# At 912 step, the loss is: 4.027394771575928
# At 913 step, the loss is: 4.100422382354736
# At 914 step, the loss is: 3.892606258392334
# At 915 step, the loss is: 4.022945880889893
# At 916 step, the loss is: 4.049958229064941
# At 917 step, the loss is: 3.9267842769622803
# At 918 step, the loss is: 4.028713703155518
# At 919 step, the loss is: 3.8704299926757812
# At 920 step, the loss is: 4.065439701080322
# At 921 step, the loss is: 4.096131801605225
# At 922 step, the loss is: 4.00990104675293
# At 923 step, the loss is: 3.9512956142425537
# At 924 step, the loss is: 3.865191698074341
# At 925 step, the loss is: 3.84480881690979
# At 926 step, the loss is: 3.8458569049835205
# At 927 step, the loss is: 3.8924567699432373
# At 928 step, the loss is: 3.9596974849700928
# At 929 step, the loss is: 4.156173229217529
# At 930 step, the loss is: 4.082523345947266
# At 931 step, the loss is: 3.9611093997955322
# At 932 step, the loss is: 4.2378997802734375
# At 933 step, the loss is: 4.110589504241943
# At 934 step, the loss is: 4.078871250152588
# At 935 step, the loss is: 4.223181247711182
# At 936 step, the loss is: 3.8450582027435303
# At 937 step, the loss is: 4.067656517028809
# At 938 step, the loss is: 4.176558971405029
# At 939 step, the loss is: 4.132552623748779
# At 940 step, the loss is: 3.8556180000305176
# At 941 step, the loss is: 4.1406450271606445
# At 942 step, the loss is: 3.999974250793457
# At 943 step, the loss is: 3.8732035160064697
# At 944 step, the loss is: 3.8259212970733643
# At 945 step, the loss is: 4.051176071166992
# At 946 step, the loss is: 3.866103410720825
# At 947 step, the loss is: 3.9852099418640137
# At 948 step, the loss is: 3.956212043762207
# At 949 step, the loss is: 4.261175632476807
# At 950 step, the loss is: 3.8098080158233643
# At 951 step, the loss is: 4.148460388183594
# At 952 step, the loss is: 3.872507095336914
# At 953 step, the loss is: 4.015089988708496
# At 954 step, the loss is: 4.119472980499268
# At 955 step, the loss is: 4.08681583404541
# At 956 step, the loss is: 3.768399238586426
# At 957 step, the loss is: 4.108249187469482
# At 958 step, the loss is: 4.19142484664917
# At 959 step, the loss is: 4.192497253417969
# At 960 step, the loss is: 4.1829657554626465
# At 961 step, the loss is: 3.786561965942383
# At 962 step, the loss is: 3.644090414047241
# At 963 step, the loss is: 4.452023506164551
# At 964 step, the loss is: 3.8154385089874268
# At 965 step, the loss is: 4.262231349945068
# At 966 step, the loss is: 3.922222137451172
# At 967 step, the loss is: 3.7000694274902344
# At 968 step, the loss is: 3.8931407928466797
# At 969 step, the loss is: 4.013412952423096
# At 970 step, the loss is: 4.019686698913574
# At 971 step, the loss is: 3.982041835784912
# At 972 step, the loss is: 4.333452224731445
# At 973 step, the loss is: 4.097599029541016
# At 974 step, the loss is: 3.879261016845703
# At 975 step, the loss is: 3.9031736850738525
# At 976 step, the loss is: 3.8516721725463867
# At 977 step, the loss is: 4.047008037567139
# At 978 step, the loss is: 3.984508514404297
# At 979 step, the loss is: 3.8846216201782227
# At 980 step, the loss is: 4.048999309539795
# At 981 step, the loss is: 3.758054494857788
# At 982 step, the loss is: 3.90623140335083
# At 983 step, the loss is: 3.8653481006622314
# At 984 step, the loss is: 3.7843494415283203
# At 985 step, the loss is: 4.225526809692383
# At 986 step, the loss is: 3.87103009223938
# At 987 step, the loss is: 3.9169251918792725
# At 988 step, the loss is: 3.9661436080932617
# At 989 step, the loss is: 3.926417112350464
# At 990 step, the loss is: 4.185546875
# At 991 step, the loss is: 3.8351807594299316
# At 992 step, the loss is: 4.016946315765381
# At 993 step, the loss is: 4.164857864379883
# At 994 step, the loss is: 4.109921932220459
# At 995 step, the loss is: 4.263358116149902
# At 996 step, the loss is: 4.04870080947876
# At 997 step, the loss is: 4.364892959594727
# At 998 step, the loss is: 3.9920494556427
# At 999 step, the loss is: 3.7934422492980957
# At 1000 step, the loss is: 4.150165557861328
# At 1001 step, the loss is: 4.216799736022949
# At 1002 step, the loss is: 3.9369940757751465
# At 1003 step, the loss is: 3.9189107418060303
# At 1004 step, the loss is: 3.7682905197143555
# At 1005 step, the loss is: 4.128757953643799
# At 1006 step, the loss is: 3.983942747116089
# At 1007 step, the loss is: 3.9368534088134766
# At 1008 step, the loss is: 4.02113676071167
# At 1009 step, the loss is: 3.918844699859619
# At 1010 step, the loss is: 4.034447193145752
# At 1011 step, the loss is: 3.9323067665100098
# At 1012 step, the loss is: 4.222546577453613
# At 1013 step, the loss is: 3.818422555923462
# At 1014 step, the loss is: 3.9541015625
# At 1015 step, the loss is: 4.108097553253174
# At 1016 step, the loss is: 3.8099331855773926
# At 1017 step, the loss is: 3.984905958175659
# At 1018 step, the loss is: 4.136724472045898
# At 1019 step, the loss is: 3.7678370475769043
# At 1020 step, the loss is: 3.877300262451172
# At 1021 step, the loss is: 3.979295492172241
# At 1022 step, the loss is: 3.890338659286499
# At 1023 step, the loss is: 3.9599499702453613
# At 1024 step, the loss is: 3.9931395053863525
# At 1025 step, the loss is: 3.9040443897247314
# At 1026 step, the loss is: 4.085655212402344
# At 1027 step, the loss is: 3.7803242206573486
# At 1028 step, the loss is: 4.11818265914917
# At 1029 step, the loss is: 3.786203145980835
# At 1030 step, the loss is: 4.12564754486084
# At 1031 step, the loss is: 4.065511703491211
# At 1032 step, the loss is: 4.070086479187012
# At 1033 step, the loss is: 4.0157790184021
# At 1034 step, the loss is: 4.185105323791504
# At 1035 step, the loss is: 3.9919044971466064
# At 1036 step, the loss is: 3.8480918407440186
# At 1037 step, the loss is: 4.317684173583984
# At 1038 step, the loss is: 4.027384281158447
# At 1039 step, the loss is: 4.122754096984863
# At 1040 step, the loss is: 4.075222492218018
# At 1041 step, the loss is: 4.056626796722412
# At 1042 step, the loss is: 4.17529296875
# At 1043 step, the loss is: 3.669403553009033
# At 1044 step, the loss is: 3.708385467529297
# At 1045 step, the loss is: 3.9721884727478027
# At 1046 step, the loss is: 4.077019214630127
# At 1047 step, the loss is: 3.788337230682373
# At 1048 step, the loss is: 4.180709362030029
# At 1049 step, the loss is: 3.9413864612579346
# At 1050 step, the loss is: 4.008324146270752
# At 1051 step, the loss is: 3.966122627258301
# At 1052 step, the loss is: 4.183557510375977
# At 1053 step, the loss is: 3.922839879989624
# At 1054 step, the loss is: 4.066521644592285
# At 1055 step, the loss is: 4.101029872894287
# At 1056 step, the loss is: 3.906336784362793
# At 1057 step, the loss is: 3.9303109645843506
# At 1058 step, the loss is: 3.999227523803711
# At 1059 step, the loss is: 4.112461090087891
# At 1060 step, the loss is: 3.948160171508789
# At 1061 step, the loss is: 3.7912240028381348
# At 1062 step, the loss is: 4.050410270690918
# At 1063 step, the loss is: 3.7636916637420654
# At 1064 step, the loss is: 3.9425179958343506
# At 1065 step, the loss is: 4.046986103057861
# At 1066 step, the loss is: 3.9096145629882812
# At 1067 step, the loss is: 4.194312572479248
# At 1068 step, the loss is: 3.9919278621673584
# At 1069 step, the loss is: 3.7414164543151855
# At 1070 step, the loss is: 4.055549621582031
# At 1071 step, the loss is: 3.9002130031585693
# At 1072 step, the loss is: 4.190759181976318
# At 1073 step, the loss is: 3.8056373596191406
# At 1074 step, the loss is: 4.028661727905273
# At 1075 step, the loss is: 3.6336007118225098
# At 1076 step, the loss is: 3.8155248165130615
# At 1077 step, the loss is: 3.6913349628448486
# At 1078 step, the loss is: 4.09511661529541
# At 1079 step, the loss is: 3.708622932434082
# At 1080 step, the loss is: 3.770181179046631
# At 1081 step, the loss is: 4.106333255767822
# At 1082 step, the loss is: 3.836345911026001
# At 1083 step, the loss is: 3.9536166191101074
# At 1084 step, the loss is: 3.7960317134857178
# At 1085 step, the loss is: 3.8861196041107178
# At 1086 step, the loss is: 4.183292865753174
# At 1087 step, the loss is: 3.6684327125549316
# At 1088 step, the loss is: 3.7752182483673096
# At 1089 step, the loss is: 3.9495973587036133
# ...
# At 9649 step, the loss is: 2.2653748989105225
# At 9650 step, the loss is: 2.693786382675171
# At 9651 step, the loss is: 2.7163619995117188
# At 9652 step, the loss is: 2.3306665420532227
# At 9653 step, the loss is: 2.601118803024292
# At 9654 step, the loss is: 2.2880728244781494
# At 9655 step, the loss is: 3.17836856842041
# At 9656 step, the loss is: 2.5923702716827393
# At 9657 step, the loss is: 2.5919599533081055
# At 9658 step, the loss is: 2.163806676864624
# At 9659 step, the loss is: 2.1344642639160156
# At 9660 step, the loss is: 2.2787046432495117
# At 9661 step, the loss is: 2.597175359725952
# At 9662 step, the loss is: 2.787102460861206
# At 9663 step, the loss is: 2.9650256633758545
# At 9664 step, the loss is: 2.903787612915039
# At 9665 step, the loss is: 2.22652006149292
# At 9666 step, the loss is: 2.493398666381836
# At 9667 step, the loss is: 2.4227967262268066
# At 9668 step, the loss is: 2.477511405944824
# At 9669 step, the loss is: 2.6983089447021484
# At 9670 step, the loss is: 2.6893744468688965
# At 9671 step, the loss is: 2.3151021003723145
# At 9672 step, the loss is: 2.5372159481048584
# At 9673 step, the loss is: 2.37457013130188
# At 9674 step, the loss is: 2.405120372772217
# At 9675 step, the loss is: 2.5845205783843994
# At 9676 step, the loss is: 2.6220955848693848
# At 9677 step, the loss is: 2.548353672027588
# At 9678 step, the loss is: 2.66195011138916
# At 9679 step, the loss is: 2.3579888343811035
# At 9680 step, the loss is: 2.407776355743408
# At 9681 step, the loss is: 2.7721095085144043
# At 9682 step, the loss is: 2.6085550785064697
# At 9683 step, the loss is: 2.5209009647369385
# At 9684 step, the loss is: 2.727613687515259
# At 9685 step, the loss is: 2.708549737930298
# At 9686 step, the loss is: 2.9737091064453125
# At 9687 step, the loss is: 2.595520257949829
# At 9688 step, the loss is: 2.516112804412842
# At 9689 step, the loss is: 2.7958977222442627
# At 9690 step, the loss is: 2.464564323425293
# At 9691 step, the loss is: 2.629310369491577
# At 9692 step, the loss is: 2.4797611236572266
# At 9693 step, the loss is: 2.843109369277954
# At 9694 step, the loss is: 2.12841796875
# At 9695 step, the loss is: 2.7321126461029053
# At 9696 step, the loss is: 2.433237075805664
# At 9697 step, the loss is: 2.5916171073913574
# At 9698 step, the loss is: 2.9152536392211914
# At 9699 step, the loss is: 2.5372414588928223
# At 9700 step, the loss is: 2.654458522796631
# At 9701 step, the loss is: 2.5071678161621094
# At 9702 step, the loss is: 2.4342823028564453
# At 9703 step, the loss is: 2.4508895874023438
# At 9704 step, the loss is: 2.4744269847869873
# At 9705 step, the loss is: 2.5859553813934326
# At 9706 step, the loss is: 2.5185022354125977
# At 9707 step, the loss is: 2.6077523231506348
# At 9708 step, the loss is: 2.269235372543335
# At 9709 step, the loss is: 2.2304911613464355
# At 9710 step, the loss is: 2.6383614540100098
# At 9711 step, the loss is: 2.5753915309906006
# At 9712 step, the loss is: 2.4820964336395264
# At 9713 step, the loss is: 2.097534656524658
# At 9714 step, the loss is: 2.83809232711792
# At 9715 step, the loss is: 2.259481191635132
# At 9716 step, the loss is: 2.435107707977295
# At 9717 step, the loss is: 2.622908353805542
# At 9718 step, the loss is: 2.9525859355926514
# At 9719 step, the loss is: 2.4748177528381348
# At 9720 step, the loss is: 2.6965506076812744
# At 9721 step, the loss is: 2.3558902740478516
# At 9722 step, the loss is: 2.021688461303711
# At 9723 step, the loss is: 2.5693368911743164
# At 9724 step, the loss is: 2.4626712799072266
# At 9725 step, the loss is: 2.4262688159942627
# At 9726 step, the loss is: 2.4036808013916016
# At 9727 step, the loss is: 2.6315131187438965
# At 9728 step, the loss is: 2.399852752685547
# At 9729 step, the loss is: 2.6436052322387695
# At 9730 step, the loss is: 2.5204720497131348
# At 9731 step, the loss is: 2.908790111541748
# At 9732 step, the loss is: 2.707256317138672
# At 9733 step, the loss is: 2.5226266384124756
# At 9734 step, the loss is: 2.4319005012512207
# At 9735 step, the loss is: 2.6421191692352295
# At 9736 step, the loss is: 2.576408863067627
# At 9737 step, the loss is: 3.221020221710205
# At 9738 step, the loss is: 2.6133506298065186
# At 9739 step, the loss is: 2.382549524307251
# At 9740 step, the loss is: 2.449265480041504
# At 9741 step, the loss is: 2.969348669052124
# At 9742 step, the loss is: 2.882908344268799
# At 9743 step, the loss is: 2.504450798034668
# At 9744 step, the loss is: 2.402103900909424
# At 9745 step, the loss is: 2.5258841514587402
# At 9746 step, the loss is: 2.4364027976989746
# At 9747 step, the loss is: 2.620838165283203
# At 9748 step, the loss is: 2.7602035999298096
# At 9749 step, the loss is: 2.8406646251678467
# At 9750 step, the loss is: 2.7313528060913086
# At 9751 step, the loss is: 2.7674684524536133
# At 9752 step, the loss is: 2.479560375213623
# At 9753 step, the loss is: 2.484527826309204
# At 9754 step, the loss is: 2.624530792236328
# At 9755 step, the loss is: 2.53664493560791
# At 9756 step, the loss is: 2.811073064804077
# At 9757 step, the loss is: 2.6221184730529785
# At 9758 step, the loss is: 2.489414930343628
# At 9759 step, the loss is: 2.556119918823242
# At 9760 step, the loss is: 2.5764951705932617
# At 9761 step, the loss is: 2.5320699214935303
# At 9762 step, the loss is: 2.466536045074463
# At 9763 step, the loss is: 2.368985891342163
# At 9764 step, the loss is: 2.153111457824707
# At 9765 step, the loss is: 2.2493178844451904
# At 9766 step, the loss is: 2.203472137451172
# At 9767 step, the loss is: 2.817531108856201
# At 9768 step, the loss is: 2.5461041927337646
# At 9769 step, the loss is: 2.343834161758423
# At 9770 step, the loss is: 2.447460174560547
# At 9771 step, the loss is: 2.6359643936157227
# At 9772 step, the loss is: 2.5148158073425293
# At 9773 step, the loss is: 2.807725191116333
# At 9774 step, the loss is: 2.728834390640259
# At 9775 step, the loss is: 2.5443103313446045
# At 9776 step, the loss is: 2.7022368907928467
# At 9777 step, the loss is: 2.408317804336548
# At 9778 step, the loss is: 2.529236078262329
# At 9779 step, the loss is: 2.884228229522705
# At 9780 step, the loss is: 2.810852527618408
# At 9781 step, the loss is: 2.9587392807006836
# At 9782 step, the loss is: 2.3783581256866455
# At 9783 step, the loss is: 2.517279624938965
# At 9784 step, the loss is: 2.399900197982788
# At 9785 step, the loss is: 2.6128549575805664
# At 9786 step, the loss is: 2.6276981830596924
# At 9787 step, the loss is: 2.344637155532837
# At 9788 step, the loss is: 2.703068733215332
# At 9789 step, the loss is: 2.520209312438965
# At 9790 step, the loss is: 2.680720567703247
# At 9791 step, the loss is: 2.3794655799865723
# At 9792 step, the loss is: 2.778196334838867
# At 9793 step, the loss is: 2.7512903213500977
# At 9794 step, the loss is: 2.556612491607666
# At 9795 step, the loss is: 2.1881301403045654
# At 9796 step, the loss is: 2.5027408599853516
# At 9797 step, the loss is: 2.585092544555664
# At 9798 step, the loss is: 2.497770309448242
# At 9799 step, the loss is: 2.3398497104644775
# At 9800 step, the loss is: 2.6260313987731934
# At 9801 step, the loss is: 2.8066904544830322
# At 9802 step, the loss is: 2.4649269580841064
# At 9803 step, the loss is: 2.6069929599761963
# At 9804 step, the loss is: 2.6022346019744873
# At 9805 step, the loss is: 2.5142974853515625
# At 9806 step, the loss is: 2.742518663406372
# At 9807 step, the loss is: 2.907609224319458
# At 9808 step, the loss is: 2.529907464981079
# At 9809 step, the loss is: 2.860485076904297
# At 9810 step, the loss is: 2.2761340141296387
# At 9811 step, the loss is: 2.4547386169433594
# At 9812 step, the loss is: 2.6794514656066895
# At 9813 step, the loss is: 2.4814043045043945
# At 9814 step, the loss is: 2.4687023162841797
# At 9815 step, the loss is: 2.1887991428375244
# At 9816 step, the loss is: 2.5992822647094727
# At 9817 step, the loss is: 2.3308017253875732
# At 9818 step, the loss is: 2.7303504943847656
# At 9819 step, the loss is: 2.375950336456299
# At 9820 step, the loss is: 2.9844233989715576
# At 9821 step, the loss is: 2.7549312114715576
# At 9822 step, the loss is: 2.2741785049438477
# At 9823 step, the loss is: 2.8137147426605225
# At 9824 step, the loss is: 2.733225107192993
# At 9825 step, the loss is: 2.2917416095733643
# At 9826 step, the loss is: 2.7846179008483887
# At 9827 step, the loss is: 2.163464069366455
# At 9828 step, the loss is: 2.467243194580078
# At 9829 step, the loss is: 2.420189619064331
# At 9830 step, the loss is: 2.659198522567749
# At 9831 step, the loss is: 2.73640513420105
# At 9832 step, the loss is: 2.5068886280059814
# At 9833 step, the loss is: 2.556938886642456
# At 9834 step, the loss is: 2.504034996032715
# At 9835 step, the loss is: 2.443087100982666
# At 9836 step, the loss is: 2.671285629272461
# At 9837 step, the loss is: 2.9141147136688232
# At 9838 step, the loss is: 2.8763060569763184
# At 9839 step, the loss is: 2.366969347000122
# At 9840 step, the loss is: 2.4802913665771484
# At 9841 step, the loss is: 2.74369478225708
# At 9842 step, the loss is: 2.199648141860962
# At 9843 step, the loss is: 2.8304455280303955
# At 9844 step, the loss is: 2.758300304412842
# At 9845 step, the loss is: 2.66937255859375
# At 9846 step, the loss is: 2.2548038959503174
# At 9847 step, the loss is: 2.488551616668701
# At 9848 step, the loss is: 2.5520386695861816
# At 9849 step, the loss is: 2.527437448501587
# At 9850 step, the loss is: 2.2668230533599854
# At 9851 step, the loss is: 2.6794135570526123
# At 9852 step, the loss is: 2.1551246643066406
# At 9853 step, the loss is: 2.798593759536743
# At 9854 step, the loss is: 2.077226161956787
# At 9855 step, the loss is: 2.6752517223358154
# At 9856 step, the loss is: 2.657665729522705
# At 9857 step, the loss is: 2.5823843479156494
# At 9858 step, the loss is: 2.284879446029663
# At 9859 step, the loss is: 3.0016350746154785
# At 9860 step, the loss is: 2.7178854942321777
# At 9861 step, the loss is: 2.402209758758545
# At 9862 step, the loss is: 2.4812047481536865
# At 9863 step, the loss is: 2.6220650672912598
# At 9864 step, the loss is: 2.767592668533325
# At 9865 step, the loss is: 2.8751158714294434
# At 9866 step, the loss is: 2.3306963443756104
# At 9867 step, the loss is: 2.62296724319458
# At 9868 step, the loss is: 2.2690930366516113
# At 9869 step, the loss is: 2.615037202835083
# At 9870 step, the loss is: 2.310145616531372
# At 9871 step, the loss is: 2.6811771392822266
# At 9872 step, the loss is: 2.5598342418670654
# At 9873 step, the loss is: 2.4831786155700684
# At 9874 step, the loss is: 2.4259696006774902
# At 9875 step, the loss is: 2.5936546325683594
# At 9876 step, the loss is: 2.1845717430114746
# At 9877 step, the loss is: 2.7627007961273193
# At 9878 step, the loss is: 2.598954677581787
# At 9879 step, the loss is: 2.3830158710479736
# At 9880 step, the loss is: 2.5716540813446045
# At 9881 step, the loss is: 2.598478317260742
# At 9882 step, the loss is: 2.4901673793792725
# At 9883 step, the loss is: 2.8499596118927
# At 9884 step, the loss is: 2.510749340057373
# At 9885 step, the loss is: 2.3134384155273438
# At 9886 step, the loss is: 2.5963573455810547
# At 9887 step, the loss is: 2.5398755073547363
# At 9888 step, the loss is: 2.446103096008301
# At 9889 step, the loss is: 2.4380481243133545
# At 9890 step, the loss is: 2.5692856311798096
# At 9891 step, the loss is: 2.2459614276885986
# At 9892 step, the loss is: 2.37882399559021
# At 9893 step, the loss is: 2.5382635593414307
# At 9894 step, the loss is: 2.678663969039917
# At 9895 step, the loss is: 2.8308470249176025
# At 9896 step, the loss is: 2.5234265327453613
# At 9897 step, the loss is: 2.808824062347412
# At 9898 step, the loss is: 2.5771074295043945
# At 9899 step, the loss is: 2.4714927673339844
# At 9900 step, the loss is: 2.3232758045196533
# At 9901 step, the loss is: 2.550096035003662
# At 9902 step, the loss is: 2.446720600128174
# At 9903 step, the loss is: 2.3831963539123535
# At 9904 step, the loss is: 2.3445253372192383
# At 9905 step, the loss is: 2.5955448150634766
# At 9906 step, the loss is: 2.7302379608154297
# At 9907 step, the loss is: 2.3967416286468506
# At 9908 step, the loss is: 2.1213769912719727
# At 9909 step, the loss is: 2.481445789337158
# At 9910 step, the loss is: 2.127260208129883
# At 9911 step, the loss is: 2.623664379119873
# At 9912 step, the loss is: 2.1939303874969482
# At 9913 step, the loss is: 2.604811668395996
# At 9914 step, the loss is: 2.796945571899414
# At 9915 step, the loss is: 2.1801750659942627
# At 9916 step, the loss is: 2.4854626655578613
# At 9917 step, the loss is: 2.5796024799346924
# At 9918 step, the loss is: 2.417734384536743
# At 9919 step, the loss is: 2.6176252365112305
# At 9920 step, the loss is: 2.539161205291748
# At 9921 step, the loss is: 2.510371685028076
# At 9922 step, the loss is: 2.8361380100250244
# At 9923 step, the loss is: 2.2887628078460693
# At 9924 step, the loss is: 2.440556287765503
# At 9925 step, the loss is: 2.6143441200256348
# At 9926 step, the loss is: 2.5120389461517334
# At 9927 step, the loss is: 2.7454798221588135
# At 9928 step, the loss is: 2.2059574127197266
# At 9929 step, the loss is: 2.452799081802368
# At 9930 step, the loss is: 2.3005785942077637
# At 9931 step, the loss is: 2.3339686393737793
# At 9932 step, the loss is: 2.607142210006714
# At 9933 step, the loss is: 2.7951271533966064
# At 9934 step, the loss is: 2.259608030319214
# At 9935 step, the loss is: 2.406376361846924
# At 9936 step, the loss is: 2.7992238998413086
# At 9937 step, the loss is: 2.5754194259643555
# At 9938 step, the loss is: 2.631934404373169
# At 9939 step, the loss is: 2.314993143081665
# At 9940 step, the loss is: 2.1323249340057373
# At 9941 step, the loss is: 2.5582664012908936
# At 9942 step, the loss is: 2.7764453887939453
# At 9943 step, the loss is: 2.611154556274414
# At 9944 step, the loss is: 2.728973150253296
# At 9945 step, the loss is: 2.195533514022827
# At 9946 step, the loss is: 2.60286283493042
# At 9947 step, the loss is: 2.577165126800537
# At 9948 step, the loss is: 2.4227278232574463
# At 9949 step, the loss is: 2.413727283477783
# At 9950 step, the loss is: 2.6995139122009277
# At 9951 step, the loss is: 2.6311323642730713
# At 9952 step, the loss is: 2.1180403232574463
# At 9953 step, the loss is: 2.0815515518188477
# At 9954 step, the loss is: 2.8011977672576904
# At 9955 step, the loss is: 2.314152956008911
# At 9956 step, the loss is: 2.699826717376709
# At 9957 step, the loss is: 2.381269693374634
# At 9958 step, the loss is: 2.529714822769165
# At 9959 step, the loss is: 2.590276002883911
# At 9960 step, the loss is: 2.5874619483947754
# At 9961 step, the loss is: 2.423642158508301
# At 9962 step, the loss is: 2.660912275314331
# At 9963 step, the loss is: 2.4758753776550293
# At 9964 step, the loss is: 2.537461757659912
# At 9965 step, the loss is: 2.4842426776885986
# At 9966 step, the loss is: 2.448469877243042
# At 9967 step, the loss is: 2.3850772380828857
# At 9968 step, the loss is: 2.47377872467041
# At 9969 step, the loss is: 2.6609177589416504
# At 9970 step, the loss is: 2.3559515476226807
# At 9971 step, the loss is: 2.5253515243530273
# At 9972 step, the loss is: 2.587867259979248
# At 9973 step, the loss is: 2.5647847652435303
# At 9974 step, the loss is: 2.760293483734131
# At 9975 step, the loss is: 2.4653124809265137
# At 9976 step, the loss is: 2.652989387512207
# At 9977 step, the loss is: 2.481062650680542
# At 9978 step, the loss is: 2.500110149383545
# At 9979 step, the loss is: 2.6477601528167725
# At 9980 step, the loss is: 2.7114334106445312
# At 9981 step, the loss is: 2.4763906002044678
# At 9982 step, the loss is: 2.3946356773376465
# At 9983 step, the loss is: 2.4962997436523438
# At 9984 step, the loss is: 2.4657397270202637
# At 9985 step, the loss is: 2.340200901031494
# At 9986 step, the loss is: 2.393413782119751
# At 9987 step, the loss is: 2.7049648761749268
# At 9988 step, the loss is: 2.575773000717163
# At 9989 step, the loss is: 2.3649332523345947
# At 9990 step, the loss is: 2.7654716968536377
# At 9991 step, the loss is: 2.715590715408325
# At 9992 step, the loss is: 2.5310792922973633
# At 9993 step, the loss is: 2.297757625579834
# At 9994 step, the loss is: 2.555663585662842
# At 9995 step, the loss is: 2.6356186866760254
# At 9996 step, the loss is: 2.28524112701416
# At 9997 step, the loss is: 2.608445167541504
# At 9998 step, the loss is: 2.2775745391845703
# At 9999 step, the loss is: 2.7421514987945557

# %%
encoded = model.generate(idx=torch.zeros((1,1), dtype=torch.long), max_new_tokens=100)[0].tolist()
decoded = decode(encoded)
decoded
# Out:
# "\nA'Te.\njs\nbeZvimm? mad antho hayerstomy, h IFOWk, whercqHassclly.\nING pe in, is, ounnsto?pa vig m BGB"
